# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

# %%
dates = {}
i = 0
df_final = pd.DataFrame(list(range(17)), columns=['hours_in_future'])

# Iterate over all files in the directory
for file_name in sorted(os.listdir(os.getcwd()+'/forecasts')):
        
    df = pd.read_csv(os.getcwd()+f'/forecasts/{file_name}')
    
    if len(df) != 17: continue

    date, hour = file_name.split('_')[2].split("-")
    if f"{date[6:8]}-{date[4:6]}" in dates.keys():
        dates[f"{date[6:8]}-{date[4:6]}"].append(hour[:2])
    else:
        dates[f"{date[6:8]}-{date[4:6]}"] = [hour[:2]]

    df_final[f'forecast_{date[6:8]}-{date[4:6]}-{hour[:2]}'] = list(df.temp_air)
    i += 1
        
df_final = df_final.drop('hours_in_future', axis = 1)
df_final = df_final.dropna(axis=1, how='any')

print(f"\nWe have {len(df_final.columns.to_list())} 16-hour forecasts for hours in {len(dates)} different days.\n")
display(df_final)
# Out:
# /var/folders/0x/l1m3sdhn7r59npk394yrpzk40000gn/T/ipykernel_2065/3945976618.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[f'forecast_{date[6:8]}-{date[4:6]}-{hour[:2]}'] = list(df.temp_air)
# We have 4098 16-hour forecasts for hours in 200 different days.
#     forecast_19-05-22  forecast_19-05-23  forecast_20-05-00  \
# 0            8.574249           8.087067           7.755402
# 1            8.101715           7.680145           7.205566
# 2            7.490875           7.224640           6.954010
# 3            7.127899           6.891022           6.521301
# 4            6.887970           6.565460           6.061096
# 5            6.492493           6.201996           5.638031
# ...

# %%
'''
list_of_columns = df_final.columns.to_list()
thomas = {}

for col in list_of_columns:
    thomas[col[:-2]] = [np.nan]*17
#print(thomas)

previous_column = ""

for column in list_of_columns:

    # If we already have a point at that time
    if thomas[column[:-2]] != [np.nan]*17

        for j in range(17):
            if int(column[-2:]) == int(previous_column[-2:]) + j:
        
                print(f"The true value for {previous_column[:-2]} at hour {j} is {df_final[column][0]}\n")
                thomas[previous_column[:-2]][j] = df_final[column][0]

    previous_column = column

print(thomas)
'''
# Out:
# '\nlist_of_columns = df_final.columns.to_list()\nthomas = {}\n\nfor col in list_of_columns:\n    thomas[col[:-2]] = [np.nan]*17\n#print(thomas)\n\nprevious_column = ""\n\nfor column in list_of_columns:\n\n    # If we already have a point at that time\n    if thomas[column[:-2]] != [np.nan]*17\n\n        for j in range(17):\n            if int(column[-2:]) == int(previous_column[-2:]) + j:\n        \n                print(f"The true value for {previous_column[:-2]} at hour {j} is {df_final[column][0]}\n")\n                thomas[previous_column[:-2]][j] = df_final[column][0]\n\n    previous_column = column\n\nprint(thomas)\n'
